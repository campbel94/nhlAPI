# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import json
import requests

# %% [markdown]
# `GET` https://statsapi.web.nhl.com/api/v1/standings Returns ordered standings data
# for each team broken up by divisions

# %%
# Create url for API call.
url = 'https://statsapi.web.nhl.com/api/v1/standings'

# %%
# Submit request
# This returns resposne object
requests.get(url)
# Out:
# <Response [200]>

# %%
res = requests.get(url)
res.json()
# Out:
# {'copyright': 'NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. © NHL 2021. All Rights Reserved.',
#  'records': [{'standingsType': 'regularSeason',
#    'league': {'id': 133,
#     'name': 'National Hockey League',
#     'link': '/api/v1/league/133'},
#    'division': {'id': 27,
#     'name': 'Honda West',
#     'link': '/api/v1/divisions/27'},
#    'conference': {'id': 0, 'name': '', 'link': '/api/v1/conferences/0'},
#    'teamRecords': [{'team': {'id': 21,
#       'name': 'Colorado Avalanche',
#       'link': '/api/v1/teams/21'},
#      'leagueRecord': {'wins': 39, 'losses': 13, 'ot': 4, 'type': 'league'},
#      'regulationWins': 35,
#      'goalsAgainst': 133,
#      'goalsScored': 197,
#      'points': 82,
#      'divisionRank': '1',
#      'divisionL10Rank': '1',
#      'divisionRoadRank': '2',
#      'divisionHomeRank': '1',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '1',
#      'leagueL10Rank': '1',
#      'leagueRoadRank': '5',
#      'leagueHomeRank': '1',
#      'wildCardRank': '0',
#      'row': 39,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'wins', 'streakNumber': 5, 'streakCode': 'W5'},
#      'clinchIndicator': 'p',
#      'pointsPercentage': 0.7321428571428571,
#      'ppDivisionRank': '1',
#      'ppConferenceRank': '1',
#      'ppLeagueRank': '1',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 54,
#       'name': 'Vegas Golden Knights',
#       'link': '/api/v1/teams/54'},
#      'leagueRecord': {'wins': 40, 'losses': 14, 'ot': 2, 'type': 'league'},
#      'regulationWins': 30,
#      'goalsAgainst': 124,
#      'goalsScored': 191,
#      'points': 82,
#      'divisionRank': '2',
#      'divisionL10Rank': '3',
#      'divisionRoadRank': '1',
#      'divisionHomeRank': '2',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '2',
#      'leagueL10Rank': '10',
#      'leagueRoadRank': '4',
#      'leagueHomeRank': '5',
#      'wildCardRank': '0',
#      'row': 39,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'wins', 'streakNumber': 1, 'streakCode': 'W1'},
#      'clinchIndicator': 'x',
#      'pointsPercentage': 0.7321428571428571,
#      'ppDivisionRank': '2',
#      'ppConferenceRank': '2',
#      'ppLeagueRank': '2',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 30, 'name': 'Minnesota Wild', 'link': '/api/v1/teams/30'},
#      'leagueRecord': {'wins': 35, 'losses': 16, 'ot': 5, 'type': 'league'},
#      'regulationWins': 27,
#      'goalsAgainst': 160,
#      'goalsScored': 181,
#      'points': 75,
#      'divisionRank': '3',
#      'divisionL10Rank': '4',
#      'divisionRoadRank': '4',
#      'divisionHomeRank': '3',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '9',
#      'leagueL10Rank': '15',
#      'leagueRoadRank': '12',
#      'leagueHomeRank': '6',
#      'wildCardRank': '0',
#      'row': 34,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'losses', 'streakNumber': 2, 'streakCode': 'L2'},
#      'clinchIndicator': 'x',
#      'pointsPercentage': 0.6696428571428571,
#      'ppDivisionRank': '3',
#      'ppConferenceRank': '9',
#      'ppLeagueRank': '9',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 19, 'name': 'St. Louis Blues', 'link': '/api/v1/teams/19'},
#      'leagueRecord': {'wins': 27, 'losses': 20, 'ot': 9, 'type': 'league'},
#      'regulationWins': 19,
#      'goalsAgainst': 170,
#      'goalsScored': 169,
#      'points': 63,
#      'divisionRank': '4',
#      'divisionL10Rank': '2',
#      'divisionRoadRank': '3',
#      'divisionHomeRank': '4',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '15',
#      'leagueL10Rank': '8',
#      'leagueRoadRank': '10',
#      'leagueHomeRank': '21',
#      'wildCardRank': '0',
#      'row': 25,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'wins', 'streakNumber': 3, 'streakCode': 'W3'},
#      'clinchIndicator': 'x',
#      'pointsPercentage': 0.5625,
#      'ppDivisionRank': '4',
#      'ppConferenceRank': '15',
#      'ppLeagueRank': '15',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 53, 'name': 'Arizona Coyotes', 'link': '/api/v1/teams/53'},
#      'leagueRecord': {'wins': 24, 'losses': 26, 'ot': 6, 'type': 'league'},
#      'regulationWins': 19,
#      'goalsAgainst': 176,
#      'goalsScored': 153,
#      'points': 54,
#      'divisionRank': '5',
#      'divisionL10Rank': '5',
#      'divisionRoadRank': '7',
#      'divisionHomeRank': '5',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '22',
#      'leagueL10Rank': '21',
#      'leagueRoadRank': '21',
#      'leagueHomeRank': '25',
#      'wildCardRank': '0',
#      'row': 21,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'wins', 'streakNumber': 2, 'streakCode': 'W2'},
#      'pointsPercentage': 0.48214285714285715,
#      'ppDivisionRank': '5',
#      'ppConferenceRank': '22',
#      'ppLeagueRank': '22',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 26,
#       'name': 'Los Angeles Kings',
#       'link': '/api/v1/teams/26'},
#      'leagueRecord': {'wins': 21, 'losses': 28, 'ot': 7, 'type': 'league'},
#      'regulationWins': 19,
#      'goalsAgainst': 170,
#      'goalsScored': 143,
#      'points': 49,
#      'divisionRank': '6',
#      'divisionL10Rank': '8',
#      'divisionRoadRank': '6',
#      'divisionHomeRank': '7',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '25',
#      'leagueL10Rank': '29',
#      'leagueRoadRank': '20',
#      'leagueHomeRank': '28',
#      'wildCardRank': '0',
#      'row': 20,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'losses', 'streakNumber': 2, 'streakCode': 'L2'},
#      'pointsPercentage': 0.4375,
#      'ppDivisionRank': '6',
#      'ppConferenceRank': '25',
#      'ppLeagueRank': '25',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 28, 'name': 'San Jose Sharks', 'link': '/api/v1/teams/28'},
#      'leagueRecord': {'wins': 21, 'losses': 28, 'ot': 7, 'type': 'league'},
#      'regulationWins': 15,
#      'goalsAgainst': 199,
#      'goalsScored': 151,
#      'points': 49,
#      'divisionRank': '7',
#      'divisionL10Rank': '6',
#      'divisionRoadRank': '8',
#      'divisionHomeRank': '6',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '26',
#      'leagueL10Rank': '26',
#      'leagueRoadRank': '26',
#      'leagueHomeRank': '27',
#      'wildCardRank': '0',
#      'row': 16,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'losses', 'streakNumber': 1, 'streakCode': 'L1'},
#      'pointsPercentage': 0.4375,
#      'ppDivisionRank': '7',
#      'ppConferenceRank': '26',
#      'ppLeagueRank': '26',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 24, 'name': 'Anaheim Ducks', 'link': '/api/v1/teams/24'},
#      'leagueRecord': {'wins': 17, 'losses': 30, 'ot': 9, 'type': 'league'},
#      'regulationWins': 11,
#      'goalsAgainst': 179,
#      'goalsScored': 126,
#      'points': 43,
#      'divisionRank': '8',
#      'divisionL10Rank': '7',
#      'divisionRoadRank': '5',
#      'divisionHomeRank': '8',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '30',
#      'leagueL10Rank': '27',
#      'leagueRoadRank': '19',
#      'leagueHomeRank': '31',
#      'wildCardRank': '0',
#      'row': 15,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'ot', 'streakNumber': 2, 'streakCode': 'OT2'},
#      'pointsPercentage': 0.38392857142857145,
#      'ppDivisionRank': '8',
#      'ppConferenceRank': '30',
#      'ppLeagueRank': '30',
#      'lastUpdated': '2021-07-08T10:37:40Z'}]},
#   {'standingsType': 'regularSeason',
#    'league': {'id': 133,
#     'name': 'National Hockey League',
#     'link': '/api/v1/league/133'},
#    'division': {'id': 26,
#     'name': 'Discover Central',
#     'link': '/api/v1/divisions/26'},
#    'conference': {'id': 0, 'name': '', 'link': '/api/v1/conferences/0'},
#    'teamRecords': [{'team': {'id': 12,
#       'name': 'Carolina Hurricanes',
#       'link': '/api/v1/teams/12'},
#      'leagueRecord': {'wins': 36, 'losses': 12, 'ot': 8, 'type': 'league'},
#      'regulationWins': 27,
#      'goalsAgainst': 136,
#      'goalsScored': 179,
#      'points': 80,
#      'divisionRank': '1',
#      'divisionL10Rank': '4',
#      'divisionRoadRank': '2',
#      'divisionHomeRank': '1',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '3',
#      'leagueL10Rank': '13',
#      'leagueRoadRank': '8',
#      'leagueHomeRank': '4',
#      'wildCardRank': '0',
#      'row': 32,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'losses', 'streakNumber': 2, 'streakCode': 'L2'},
#      'clinchIndicator': 'y',
#      'pointsPercentage': 0.7142857142857143,
#      'ppDivisionRank': '1',
#      'ppConferenceRank': '3',
#      'ppLeagueRank': '3',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 13,
#       'name': 'Florida Panthers',
#       'link': '/api/v1/teams/13'},
#      'leagueRecord': {'wins': 37, 'losses': 14, 'ot': 5, 'type': 'league'},
#      'regulationWins': 26,
#      'goalsAgainst': 153,
#      'goalsScored': 189,
#      'points': 79,
#      'divisionRank': '2',
#      'divisionL10Rank': '1',
#      'divisionRoadRank': '1',
#      'divisionHomeRank': '2',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '4',
#      'leagueL10Rank': '4',
#      'leagueRoadRank': '6',
#      'leagueHomeRank': '7',
#      'wildCardRank': '0',
#      'row': 36,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'wins', 'streakNumber': 6, 'streakCode': 'W6'},
#      'clinchIndicator': 'x',
#      'pointsPercentage': 0.7053571428571429,
#      'ppDivisionRank': '2',
#      'ppConferenceRank': '4',
#      'ppLeagueRank': '4',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 14,
#       'name': 'Tampa Bay Lightning',
#       'link': '/api/v1/teams/14'},
#      'leagueRecord': {'wins': 36, 'losses': 17, 'ot': 3, 'type': 'league'},
#      'regulationWins': 29,
#      'goalsAgainst': 147,
#      'goalsScored': 181,
#      'points': 75,
#      'divisionRank': '3',
#      'divisionL10Rank': '3',
#      'divisionRoadRank': '3',
#      'divisionHomeRank': '3',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '8',
#      'leagueL10Rank': '12',
#      'leagueRoadRank': '11',
#      'leagueHomeRank': '8',
#      'wildCardRank': '0',
#      'row': 35,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'losses', 'streakNumber': 3, 'streakCode': 'L3'},
#      'clinchIndicator': 'x',
#      'pointsPercentage': 0.6696428571428571,
#      'ppDivisionRank': '3',
#      'ppConferenceRank': '8',
#      'ppLeagueRank': '8',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 18,
#       'name': 'Nashville Predators',
#       'link': '/api/v1/teams/18'},
#      'leagueRecord': {'wins': 31, 'losses': 23, 'ot': 2, 'type': 'league'},
#      'regulationWins': 21,
#      'goalsAgainst': 154,
#      'goalsScored': 156,
#      'points': 64,
#      'divisionRank': '4',
#      'divisionL10Rank': '2',
#      'divisionRoadRank': '4',
#      'divisionHomeRank': '4',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '13',
#      'leagueL10Rank': '6',
#      'leagueRoadRank': '18',
#      'leagueHomeRank': '12',
#      'wildCardRank': '0',
#      'row': 26,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'wins', 'streakNumber': 2, 'streakCode': 'W2'},
#      'clinchIndicator': 'x',
#      'pointsPercentage': 0.5714285714285714,
#      'ppDivisionRank': '4',
#      'ppConferenceRank': '13',
#      'ppLeagueRank': '13',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 25, 'name': 'Dallas Stars', 'link': '/api/v1/teams/25'},
#      'leagueRecord': {'wins': 23, 'losses': 19, 'ot': 14, 'type': 'league'},
#      'regulationWins': 17,
#      'goalsAgainst': 154,
#      'goalsScored': 158,
#      'points': 60,
#      'divisionRank': '5',
#      'divisionL10Rank': '6',
#      'divisionRoadRank': '5',
#      'divisionHomeRank': '5',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '17',
#      'leagueL10Rank': '19',
#      'leagueRoadRank': '23',
#      'leagueHomeRank': '13',
#      'wildCardRank': '0',
#      'row': 21,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'wins', 'streakNumber': 1, 'streakCode': 'W1'},
#      'pointsPercentage': 0.5357142857142857,
#      'ppDivisionRank': '5',
#      'ppConferenceRank': '17',
#      'ppLeagueRank': '17',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 16,
#       'name': 'Chicago Blackhawks',
#       'link': '/api/v1/teams/16'},
#      'leagueRecord': {'wins': 24, 'losses': 25, 'ot': 7, 'type': 'league'},
#      'regulationWins': 15,
#      'goalsAgainst': 186,
#      'goalsScored': 161,
#      'points': 55,
#      'divisionRank': '6',
#      'divisionL10Rank': '8',
#      'divisionRoadRank': '6',
#      'divisionHomeRank': '6',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '21',
#      'leagueL10Rank': '28',
#      'leagueRoadRank': '24',
#      'leagueHomeRank': '18',
#      'wildCardRank': '0',
#      'row': 22,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'ot', 'streakNumber': 1, 'streakCode': 'OT1'},
#      'pointsPercentage': 0.49107142857142855,
#      'ppDivisionRank': '6',
#      'ppConferenceRank': '21',
#      'ppLeagueRank': '21',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 17,
#       'name': 'Detroit Red Wings',
#       'link': '/api/v1/teams/17'},
#      'leagueRecord': {'wins': 19, 'losses': 27, 'ot': 10, 'type': 'league'},
#      'regulationWins': 16,
#      'goalsAgainst': 171,
#      'goalsScored': 127,
#      'points': 48,
#      'divisionRank': '7',
#      'divisionL10Rank': '5',
#      'divisionRoadRank': '7',
#      'divisionHomeRank': '8',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '27',
#      'leagueL10Rank': '18',
#      'leagueRoadRank': '29',
#      'leagueHomeRank': '23',
#      'wildCardRank': '0',
#      'row': 17,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'ot', 'streakNumber': 1, 'streakCode': 'OT1'},
#      'pointsPercentage': 0.42857142857142855,
#      'ppDivisionRank': '7',
#      'ppConferenceRank': '27',
#      'ppLeagueRank': '27',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 29,
#       'name': 'Columbus Blue Jackets',
#       'link': '/api/v1/teams/29'},
#      'leagueRecord': {'wins': 18, 'losses': 26, 'ot': 12, 'type': 'league'},
#      'regulationWins': 12,
#      'goalsAgainst': 187,
#      'goalsScored': 137,
#      'points': 48,
#      'divisionRank': '8',
#      'divisionL10Rank': '7',
#      'divisionRoadRank': '8',
#      'divisionHomeRank': '7',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '28',
#      'leagueL10Rank': '24',
#      'leagueRoadRank': '30',
#      'leagueHomeRank': '20',
#      'wildCardRank': '0',
#      'row': 15,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'wins', 'streakNumber': 1, 'streakCode': 'W1'},
#      'pointsPercentage': 0.42857142857142855,
#      'ppDivisionRank': '8',
#      'ppConferenceRank': '28',
#      'ppLeagueRank': '28',
#      'lastUpdated': '2021-07-08T10:37:40Z'}]},
#   {'standingsType': 'regularSeason',
#    'league': {'id': 133,
#     'name': 'National Hockey League',
#     'link': '/api/v1/league/133'},
#    'division': {'id': 25,
#     'name': 'MassMutual East',
#     'link': '/api/v1/divisions/25'},
#    'conference': {'id': 0, 'name': '', 'link': '/api/v1/conferences/0'},
#    'teamRecords': [{'team': {'id': 5,
#       'name': 'Pittsburgh Penguins',
#       'link': '/api/v1/teams/5'},
#      'leagueRecord': {'wins': 37, 'losses': 16, 'ot': 3, 'type': 'league'},
#      'regulationWins': 29,
#      'goalsAgainst': 156,
#      'goalsScored': 196,
#      'points': 77,
#      'divisionRank': '1',
#      'divisionL10Rank': '1',
#      'divisionRoadRank': '3',
#      'divisionHomeRank': '1',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '5',
#      'leagueL10Rank': '2',
#      'leagueRoadRank': '13',
#      'leagueHomeRank': '2',
#      'wildCardRank': '0',
#      'row': 34,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'wins', 'streakNumber': 3, 'streakCode': 'W3'},
#      'clinchIndicator': 'y',
#      'pointsPercentage': 0.6875,
#      'ppDivisionRank': '1',
#      'ppConferenceRank': '5',
#      'ppLeagueRank': '5',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 15,
#       'name': 'Washington Capitals',
#       'link': '/api/v1/teams/15'},
#      'leagueRecord': {'wins': 36, 'losses': 15, 'ot': 5, 'type': 'league'},
#      'regulationWins': 29,
#      'goalsAgainst': 163,
#      'goalsScored': 191,
#      'points': 77,
#      'divisionRank': '2',
#      'divisionL10Rank': '2',
#      'divisionRoadRank': '1',
#      'divisionHomeRank': '4',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '7',
#      'leagueL10Rank': '7',
#      'leagueRoadRank': '2',
#      'leagueHomeRank': '11',
#      'wildCardRank': '0',
#      'row': 33,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'wins', 'streakNumber': 2, 'streakCode': 'W2'},
#      'clinchIndicator': 'x',
#      'pointsPercentage': 0.6875,
#      'ppDivisionRank': '2',
#      'ppConferenceRank': '7',
#      'ppLeagueRank': '7',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 6, 'name': 'Boston Bruins', 'link': '/api/v1/teams/6'},
#      'leagueRecord': {'wins': 33, 'losses': 16, 'ot': 7, 'type': 'league'},
#      'regulationWins': 25,
#      'goalsAgainst': 136,
#      'goalsScored': 168,
#      'points': 73,
#      'divisionRank': '3',
#      'divisionL10Rank': '3',
#      'divisionRoadRank': '2',
#      'divisionHomeRank': '3',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '10',
#      'leagueL10Rank': '11',
#      'leagueRoadRank': '9',
#      'leagueHomeRank': '10',
#      'wildCardRank': '0',
#      'row': 29,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'losses', 'streakNumber': 1, 'streakCode': 'L1'},
#      'clinchIndicator': 'x',
#      'pointsPercentage': 0.6517857142857143,
#      'ppDivisionRank': '3',
#      'ppConferenceRank': '10',
#      'ppLeagueRank': '10',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 2,
#       'name': 'New York Islanders',
#       'link': '/api/v1/teams/2'},
#      'leagueRecord': {'wins': 32, 'losses': 17, 'ot': 7, 'type': 'league'},
#      'regulationWins': 24,
#      'goalsAgainst': 128,
#      'goalsScored': 156,
#      'points': 71,
#      'divisionRank': '4',
#      'divisionL10Rank': '6',
#      'divisionRoadRank': '7',
#      'divisionHomeRank': '2',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '12',
#      'leagueL10Rank': '23',
#      'leagueRoadRank': '22',
#      'leagueHomeRank': '3',
#      'wildCardRank': '0',
#      'row': 28,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'ot', 'streakNumber': 1, 'streakCode': 'OT1'},
#      'clinchIndicator': 'x',
#      'pointsPercentage': 0.6339285714285714,
#      'ppDivisionRank': '4',
#      'ppConferenceRank': '12',
#      'ppLeagueRank': '12',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 3, 'name': 'New York Rangers', 'link': '/api/v1/teams/3'},
#      'leagueRecord': {'wins': 27, 'losses': 23, 'ot': 6, 'type': 'league'},
#      'regulationWins': 24,
#      'goalsAgainst': 157,
#      'goalsScored': 177,
#      'points': 60,
#      'divisionRank': '5',
#      'divisionL10Rank': '7',
#      'divisionRoadRank': '5',
#      'divisionHomeRank': '5',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '16',
#      'leagueL10Rank': '25',
#      'leagueRoadRank': '16',
#      'leagueHomeRank': '17',
#      'wildCardRank': '0',
#      'row': 26,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'wins', 'streakNumber': 1, 'streakCode': 'W1'},
#      'pointsPercentage': 0.5357142857142857,
#      'ppDivisionRank': '5',
#      'ppConferenceRank': '16',
#      'ppLeagueRank': '16',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 4,
#       'name': 'Philadelphia Flyers',
#       'link': '/api/v1/teams/4'},
#      'leagueRecord': {'wins': 25, 'losses': 23, 'ot': 8, 'type': 'league'},
#      'regulationWins': 17,
#      'goalsAgainst': 201,
#      'goalsScored': 163,
#      'points': 58,
#      'divisionRank': '6',
#      'divisionL10Rank': '5',
#      'divisionRoadRank': '4',
#      'divisionHomeRank': '6',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '19',
#      'leagueL10Rank': '22',
#      'leagueRoadRank': '14',
#      'leagueHomeRank': '26',
#      'wildCardRank': '0',
#      'row': 22,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'wins', 'streakNumber': 1, 'streakCode': 'W1'},
#      'pointsPercentage': 0.5178571428571429,
#      'ppDivisionRank': '6',
#      'ppConferenceRank': '19',
#      'ppLeagueRank': '19',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 1, 'name': 'New Jersey Devils', 'link': '/api/v1/teams/1'},
#      'leagueRecord': {'wins': 19, 'losses': 30, 'ot': 7, 'type': 'league'},
#      'regulationWins': 15,
#      'goalsAgainst': 194,
#      'goalsScored': 145,
#      'points': 45,
#      'divisionRank': '7',
#      'divisionL10Rank': '4',
#      'divisionRoadRank': '6',
#      'divisionHomeRank': '8',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '29',
#      'leagueL10Rank': '16',
#      'leagueRoadRank': '17',
#      'leagueHomeRank': '30',
#      'wildCardRank': '0',
#      'row': 19,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'losses', 'streakNumber': 2, 'streakCode': 'L2'},
#      'pointsPercentage': 0.4017857142857143,
#      'ppDivisionRank': '7',
#      'ppConferenceRank': '29',
#      'ppLeagueRank': '29',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 7, 'name': 'Buffalo Sabres', 'link': '/api/v1/teams/7'},
#      'leagueRecord': {'wins': 15, 'losses': 34, 'ot': 7, 'type': 'league'},
#      'regulationWins': 11,
#      'goalsAgainst': 199,
#      'goalsScored': 138,
#      'points': 37,
#      'divisionRank': '8',
#      'divisionL10Rank': '8',
#      'divisionRoadRank': '8',
#      'divisionHomeRank': '7',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '31',
#      'leagueL10Rank': '31',
#      'leagueRoadRank': '31',
#      'leagueHomeRank': '29',
#      'wildCardRank': '0',
#      'row': 11,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'losses', 'streakNumber': 2, 'streakCode': 'L2'},
#      'pointsPercentage': 0.33035714285714285,
#      'ppDivisionRank': '8',
#      'ppConferenceRank': '31',
#      'ppLeagueRank': '31',
#      'lastUpdated': '2021-07-08T10:37:40Z'}]},
#   {'standingsType': 'regularSeason',
#    'league': {'id': 133,
#     'name': 'National Hockey League',
#     'link': '/api/v1/league/133'},
#    'division': {'id': 28,
#     'name': 'Scotia North',
#     'link': '/api/v1/divisions/28'},
#    'conference': {'id': 0, 'name': '', 'link': '/api/v1/conferences/0'},
#    'teamRecords': [{'team': {'id': 10,
#       'name': 'Toronto Maple Leafs',
#       'link': '/api/v1/teams/10'},
#      'leagueRecord': {'wins': 35, 'losses': 14, 'ot': 7, 'type': 'league'},
#      'regulationWins': 29,
#      'goalsAgainst': 148,
#      'goalsScored': 187,
#      'points': 77,
#      'divisionRank': '1',
#      'divisionL10Rank': '1',
#      'divisionRoadRank': '2',
#      'divisionHomeRank': '1',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '6',
#      'leagueL10Rank': '3',
#      'leagueRoadRank': '3',
#      'leagueHomeRank': '9',
#      'wildCardRank': '0',
#      'row': 34,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'losses', 'streakNumber': 1, 'streakCode': 'L1'},
#      'clinchIndicator': 'y',
#      'pointsPercentage': 0.6875,
#      'ppDivisionRank': '1',
#      'ppConferenceRank': '6',
#      'ppLeagueRank': '6',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 22, 'name': 'Edmonton Oilers', 'link': '/api/v1/teams/22'},
#      'leagueRecord': {'wins': 35, 'losses': 19, 'ot': 2, 'type': 'league'},
#      'regulationWins': 31,
#      'goalsAgainst': 154,
#      'goalsScored': 183,
#      'points': 72,
#      'divisionRank': '2',
#      'divisionL10Rank': '3',
#      'divisionRoadRank': '1',
#      'divisionHomeRank': '2',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '11',
#      'leagueL10Rank': '9',
#      'leagueRoadRank': '1',
#      'leagueHomeRank': '14',
#      'wildCardRank': '0',
#      'row': 35,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'losses', 'streakNumber': 1, 'streakCode': 'L1'},
#      'clinchIndicator': 'x',
#      'pointsPercentage': 0.6428571428571429,
#      'ppDivisionRank': '2',
#      'ppConferenceRank': '11',
#      'ppLeagueRank': '11',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 52, 'name': 'Winnipeg Jets', 'link': '/api/v1/teams/52'},
#      'leagueRecord': {'wins': 30, 'losses': 23, 'ot': 3, 'type': 'league'},
#      'regulationWins': 24,
#      'goalsAgainst': 154,
#      'goalsScored': 170,
#      'points': 63,
#      'divisionRank': '3',
#      'divisionL10Rank': '7',
#      'divisionRoadRank': '3',
#      'divisionHomeRank': '7',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '14',
#      'leagueL10Rank': '30',
#      'leagueRoadRank': '7',
#      'leagueHomeRank': '24',
#      'wildCardRank': '0',
#      'row': 30,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'wins', 'streakNumber': 2, 'streakCode': 'W2'},
#      'clinchIndicator': 'x',
#      'pointsPercentage': 0.5625,
#      'ppDivisionRank': '3',
#      'ppConferenceRank': '14',
#      'ppLeagueRank': '14',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 8,
#       'name': 'Montréal Canadiens',
#       'link': '/api/v1/teams/8'},
#      'leagueRecord': {'wins': 24, 'losses': 21, 'ot': 11, 'type': 'league'},
#      'regulationWins': 20,
#      'goalsAgainst': 168,
#      'goalsScored': 159,
#      'points': 59,
#      'divisionRank': '4',
#      'divisionL10Rank': '5',
#      'divisionRoadRank': '4',
#      'divisionHomeRank': '5',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '18',
#      'leagueL10Rank': '17',
#      'leagueRoadRank': '15',
#      'leagueHomeRank': '19',
#      'wildCardRank': '0',
#      'row': 23,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'ot', 'streakNumber': 2, 'streakCode': 'OT2'},
#      'clinchIndicator': 'x',
#      'pointsPercentage': 0.5267857142857143,
#      'ppDivisionRank': '4',
#      'ppConferenceRank': '18',
#      'ppLeagueRank': '18',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 20, 'name': 'Calgary Flames', 'link': '/api/v1/teams/20'},
#      'leagueRecord': {'wins': 26, 'losses': 27, 'ot': 3, 'type': 'league'},
#      'regulationWins': 22,
#      'goalsAgainst': 161,
#      'goalsScored': 156,
#      'points': 55,
#      'divisionRank': '5',
#      'divisionL10Rank': '4',
#      'divisionRoadRank': '5',
#      'divisionHomeRank': '4',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '20',
#      'leagueL10Rank': '14',
#      'leagueRoadRank': '25',
#      'leagueHomeRank': '16',
#      'wildCardRank': '0',
#      'row': 25,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'wins', 'streakNumber': 1, 'streakCode': 'W1'},
#      'pointsPercentage': 0.49107142857142855,
#      'ppDivisionRank': '5',
#      'ppConferenceRank': '20',
#      'ppLeagueRank': '20',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 9, 'name': 'Ottawa Senators', 'link': '/api/v1/teams/9'},
#      'leagueRecord': {'wins': 23, 'losses': 28, 'ot': 5, 'type': 'league'},
#      'regulationWins': 18,
#      'goalsAgainst': 190,
#      'goalsScored': 157,
#      'points': 51,
#      'divisionRank': '6',
#      'divisionL10Rank': '2',
#      'divisionRoadRank': '7',
#      'divisionHomeRank': '3',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '23',
#      'leagueL10Rank': '5',
#      'leagueRoadRank': '28',
#      'leagueHomeRank': '15',
#      'wildCardRank': '0',
#      'row': 21,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'wins', 'streakNumber': 1, 'streakCode': 'W1'},
#      'pointsPercentage': 0.45535714285714285,
#      'ppDivisionRank': '6',
#      'ppConferenceRank': '23',
#      'ppLeagueRank': '23',
#      'lastUpdated': '2021-07-08T10:37:40Z'},
#     {'team': {'id': 23,
#       'name': 'Vancouver Canucks',
#       'link': '/api/v1/teams/23'},
#      'leagueRecord': {'wins': 23, 'losses': 29, 'ot': 4, 'type': 'league'},
#      'regulationWins': 17,
#      'goalsAgainst': 188,
#      'goalsScored': 151,
#      'points': 50,
#      'divisionRank': '7',
#      'divisionL10Rank': '6',
#      'divisionRoadRank': '6',
#      'divisionHomeRank': '6',
#      'conferenceRank': '0',
#      'conferenceL10Rank': '0',
#      'conferenceRoadRank': '0',
#      'conferenceHomeRank': '0',
#      'leagueRank': '24',
#      'leagueL10Rank': '20',
#      'leagueRoadRank': '27',
#      'leagueHomeRank': '22',
#      'wildCardRank': '0',
#      'row': 20,
#      'gamesPlayed': 56,
#      'streak': {'streakType': 'losses', 'streakNumber': 1, 'streakCode': 'L1'},
#      'pointsPercentage': 0.44642857142857145,
#      'ppDivisionRank': '7',
#      'ppConferenceRank': '24',
#      'ppLeagueRank': '24',
#      'lastUpdated': '2021-07-08T10:37:40Z'}]}]}

# %% [markdown]
# ### Standings Types
# `GET` https://statsapi.web.nhl.com/api/v1/standingsTypes Returns all the standings types
# to be used in order do get a specific standings
