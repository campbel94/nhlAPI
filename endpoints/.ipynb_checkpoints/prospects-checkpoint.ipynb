# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import json
import requests

# %% [markdown]
# `GET` https://statsapi.web.nhl.com/api/v1/draft/prospects Get all NHL Entry Draft prospects.<br>
# `GET` https://statsapi.web.nhl.com/api/v1/draft/prospects/ID Get an NHL Entry Draft prospect.

# %%
# Create url for API call.
url = 'https://statsapi.web.nhl.com/api/v1/draft/prospects'

# %%
# Submit request
# This returns resposne object
requests.get(url)
# Out:
# <Response [200]>

# %%
res = requests.get(url)
res.json()
# Out:
# {'copyright': 'NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. © NHL 2021. All Rights Reserved.',
#  'prospects': [{'id': 82077,
#    'fullName': 'Tristan Lennox',
#    'link': '/api/v1/draft/prospects/82077',
#    'firstName': 'Tristan',
#    'lastName': 'Lennox',
#    'birthDate': '2002-10-21',
#    'birthCity': 'Ottawa',
#    'birthStateProvince': 'ON',
#    'birthCountry': 'CAN',
#    'height': '6\' 4"',
#    'weight': 190,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'nhlPlayerId': 8482668,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'name': 'Saginaw', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'OHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 3, 'draftYear': 2021}},
#   {'id': 89143,
#    'fullName': 'Aku Koskenvuo',
#    'link': '/api/v1/draft/prospects/89143',
#    'firstName': 'Aku',
#    'lastName': 'Koskenvuo',
#    'birthDate': '2003-02-26',
#    'birthCity': 'Espoo',
#    'birthCountry': 'FIN',
#    'height': '6\' 4"',
#    'weight': 173,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'nhlPlayerId': 8482875,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 4,
#     'shortName': 'Euro Goalie',
#     'name': 'European Goalie'},
#    'amateurTeam': {'name': 'HIFK Jr.', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'FINLAND-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 4, 'draftYear': 2021}},
#   {'id': 86169,
#    'fullName': 'Olivier Adam',
#    'link': '/api/v1/draft/prospects/86169',
#    'firstName': 'Olivier',
#    'lastName': 'Adam',
#    'birthDate': '2002-05-20',
#    'birthCity': 'Drummondville',
#    'birthStateProvince': 'QC',
#    'birthCountry': 'CAN',
#    'height': '6\' 3"',
#    'weight': 178,
#    'shootsCatches': 'R',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'nhlPlayerId': 8482725,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'name': 'BLAINVILLE-BOISBRIAND',
#     'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'QMJHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 4, 'draftYear': 2021}},
#   {'id': 86447,
#    'fullName': 'Emerik Despatie',
#    'link': '/api/v1/draft/prospects/86447',
#    'firstName': 'Emerik',
#    'lastName': 'Despatie',
#    'birthDate': '2003-06-22',
#    'birthCity': 'Gatineau',
#    'birthStateProvince': 'QC',
#    'birthCountry': 'CAN',
#    'height': '6\' 1"',
#    'weight': 173,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'nhlPlayerId': 8483054,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'name': 'GATINEAU', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'QMJHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 5, 'draftYear': 2021}},
#   {'id': 87125,
#    'fullName': 'Carl Lindbom',
#    'link': '/api/v1/draft/prospects/87125',
#    'firstName': 'Carl',
#    'lastName': 'Lindbom',
#    'birthDate': '2003-05-20',
#    'birthCity': 'Stockholm',
#    'birthCountry': 'SWE',
#    'height': '6\' 0"',
#    'weight': 165,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'nhlPlayerId': 8482761,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 4,
#     'shortName': 'Euro Goalie',
#     'name': 'European Goalie'},
#    'amateurTeam': {'name': 'Djurgarden Jr.', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'SWEDEN-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 5, 'draftYear': 2021}},
#   {'id': 82080,
#    'fullName': 'Joe Vrbetic',
#    'link': '/api/v1/draft/prospects/82080',
#    'firstName': 'Joe',
#    'lastName': 'Vrbetic',
#    'birthDate': '2002-10-24',
#    'birthCity': 'Hamilton',
#    'birthStateProvince': 'ON',
#    'birthCountry': 'CAN',
#    'height': '6\' 6"',
#    'weight': 190,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'nhlPlayerId': 8482669,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'name': 'North Bay', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'OHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 6, 'draftYear': 2021}},
#   {'id': 86011,
#    'fullName': 'Tomas Suchanek',
#    'link': '/api/v1/draft/prospects/86011',
#    'firstName': 'Tomas',
#    'lastName': 'Suchanek',
#    'birthDate': '2003-04-30',
#    'birthCity': 'Prerov',
#    'birthCountry': 'CZE',
#    'height': '6\' 0"',
#    'weight': 171,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 4,
#     'shortName': 'Euro Goalie',
#     'name': 'European Goalie'},
#    'amateurTeam': {'name': 'TRI-CITY', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'WHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 6, 'draftYear': 2021}},
#   {'id': 86151,
#    'fullName': 'Francesco Lapenna',
#    'link': '/api/v1/draft/prospects/86151',
#    'firstName': 'Francesco',
#    'lastName': 'Lapenna',
#    'birthDate': '2002-07-08',
#    'birthCity': 'Laval',
#    'birthStateProvince': 'QC',
#    'birthCountry': 'CAN',
#    'height': '6\' 0"',
#    'weight': 188,
#    'shootsCatches': 'R',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'nhlPlayerId': 8483001,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'name': 'DRUMMONDVILLE', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'QMJHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 7, 'draftYear': 2021}},
#   {'id': 80548,
#    'fullName': 'Rasmus Korhonen',
#    'link': '/api/v1/draft/prospects/80548',
#    'firstName': 'Rasmus',
#    'lastName': 'Korhonen',
#    'birthDate': '2002-10-22',
#    'birthCity': 'Tampere',
#    'birthCountry': 'FIN',
#    'height': '6\' 5"',
#    'weight': 194,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'nhlPlayerId': 8482871,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 4,
#     'shortName': 'Euro Goalie',
#     'name': 'European Goalie'},
#    'amateurTeam': {'name': 'Assat Jr.', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'FINLAND-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 7, 'draftYear': 2021}},
#   {'id': 87693,
#    'fullName': 'Semyon Vyazovoi',
#    'link': '/api/v1/draft/prospects/87693',
#    'firstName': 'Semyon',
#    'lastName': 'Vyazovoi',
#    'birthDate': '2003-02-26',
#    'birthCity': 'Ufa',
#    'birthCountry': 'RUS',
#    'height': '6\' 2"',
#    'weight': 169,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'nhlPlayerId': 8482884,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 4,
#     'shortName': 'Euro Goalie',
#     'name': 'European Goalie'},
#    'amateurTeam': {'name': 'Ufa 2', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'RUSSIA-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 8, 'draftYear': 2021}},
#   {'id': 87207,
#    'fullName': 'Arsenii Sergeev',
#    'link': '/api/v1/draft/prospects/87207',
#    'firstName': 'Arsenii',
#    'lastName': 'Sergeev',
#    'birthDate': '2002-12-16',
#    'birthCity': 'Yaroslavl',
#    'birthCountry': 'RUS',
#    'height': '6\' 3"',
#    'weight': 192,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'nhlPlayerId': 8482949,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'name': 'Shreveport', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'NAHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 8, 'draftYear': 2021}},
#   {'id': 85482,
#    'fullName': 'Platon Zadorozhny',
#    'link': '/api/v1/draft/prospects/85482',
#    'firstName': 'Platon',
#    'lastName': 'Zadorozhny',
#    'birthDate': '2002-12-20',
#    'birthCity': 'Moscow',
#    'birthCountry': 'RUS',
#    'height': '6\' 1"',
#    'weight': 172,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 4,
#     'shortName': 'Euro Goalie',
#     'name': 'European Goalie'},
#    'amateurTeam': {'name': 'SPARTAK 2', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'RUSSIA-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 9, 'draftYear': 2021}},
#   {'id': 88670,
#    'fullName': 'Carter Serhyenko',
#    'link': '/api/v1/draft/prospects/88670',
#    'firstName': 'Carter',
#    'lastName': 'Serhyenko',
#    'birthDate': '2002-09-24',
#    'birthCity': 'Saskatoon',
#    'birthStateProvince': 'SK',
#    'birthCountry': 'CAN',
#    'height': '6\' 4"',
#    'weight': 193,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'nhlPlayerId': 8482773,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'name': 'PRINCE ALBERT', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'WHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 9, 'draftYear': 2021}},
#   {'id': 77359,
#    'fullName': 'Nick Malik',
#    'link': '/api/v1/draft/prospects/77359',
#    'firstName': 'Nick',
#    'lastName': 'Malik',
#    'birthDate': '2002-04-26',
#    'birthCity': 'Raleigh',
#    'birthStateProvince': 'NC',
#    'birthCountry': 'USA',
#    'height': '6\' 1"',
#    'weight': 177,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'name': 'KOOKOO', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'FINLAND', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 10, 'draftYear': 2021}},
#   {'id': 85511,
#    'fullName': 'Thomas Milic',
#    'link': '/api/v1/draft/prospects/85511',
#    'firstName': 'Thomas',
#    'lastName': 'Milic',
#    'birthDate': '2003-04-14',
#    'birthCity': 'New Westminster',
#    'birthStateProvince': 'BC',
#    'birthCountry': 'CAN',
#    'height': '6\' 0"',
#    'weight': 175,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'nhlPlayerId': 8483114,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'name': 'SEATTLE', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'WHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 10, 'draftYear': 2021}},
#   {'id': 82534,
#    'fullName': 'Brett Brochu',
#    'link': '/api/v1/draft/prospects/82534',
#    'firstName': 'Brett',
#    'lastName': 'Brochu',
#    'birthDate': '2002-09-09',
#    'birthCity': 'Belle River',
#    'birthStateProvince': 'ON',
#    'birthCountry': 'CAN',
#    'height': '5\' 11"',
#    'weight': 177,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'nhlPlayerId': 8482588,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'name': 'LONDON', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'OHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 11, 'draftYear': 2021}},
#   {'id': 82326,
#    'fullName': 'Pavel Cajan',
#    'link': '/api/v1/draft/prospects/82326',
#    'firstName': 'Pavel',
#    'lastName': 'Cajan',
#    'birthDate': '2002-10-13',
#    'birthCity': 'Pribram',
#    'birthCountry': 'CZE',
#    'height': '6\' 2"',
#    'weight': 183,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 4,
#     'shortName': 'Euro Goalie',
#     'name': 'European Goalie'},
#    'amateurTeam': {'name': 'KITCHENER', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'OHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 11, 'draftYear': 2021}},
#   {'id': 77835,
#    'fullName': 'Talyn Boyko',
#    'link': '/api/v1/draft/prospects/77835',
#    'firstName': 'Talyn',
#    'lastName': 'Boyko',
#    'birthDate': '2002-10-16',
#    'birthCity': 'Drumheller',
#    'birthStateProvince': 'AB',
#    'birthCountry': 'CAN',
#    'height': '6\' 7"',
#    'weight': 196,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'nhlPlayerId': 8482869,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'name': 'Tri-City', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'WHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 12, 'draftYear': 2021}},
#   {'id': 87182,
#    'fullName': 'Nikita Quapp',
#    'link': '/api/v1/draft/prospects/87182',
#    'firstName': 'Nikita',
#    'lastName': 'Quapp',
#    'birthDate': '2003-01-25',
#    'birthCity': 'Ravensburg',
#    'birthCountry': 'DEU',
#    'height': '6\' 3"',
#    'weight': 187,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'nhlPlayerId': 8482895,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 4,
#     'shortName': 'Euro Goalie',
#     'name': 'European Goalie'},
#    'amateurTeam': {'name': 'Krefeld', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'GERMANY', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 12, 'draftYear': 2021}},
#   {'id': 84055,
#    'fullName': 'Florian Bugl',
#    'link': '/api/v1/draft/prospects/84055',
#    'firstName': 'Florian',
#    'lastName': 'Bugl',
#    'birthDate': '2002-05-14',
#    'birthCity': 'Landshut',
#    'birthCountry': 'DEU',
#    'height': '6\' 0"',
#    'weight': 187,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 4,
#     'shortName': 'Euro Goalie',
#     'name': 'European Goalie'},
#    'amateurTeam': {'name': 'RB HOCKEY JUNIORS', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'AUSTRIA-2', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 13, 'draftYear': 2021}},
#   {'id': 89585,
#    'fullName': 'Anton Castro',
#    'link': '/api/v1/draft/prospects/89585',
#    'firstName': 'Anton',
#    'lastName': 'Castro',
#    'birthDate': '2003-01-23',
#    'birthCity': 'Mendota Heights',
#    'birthStateProvince': 'MN',
#    'birthCountry': 'USA',
#    'height': '6\' 0"',
#    'weight': 179,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'name': 'FARGO', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'USHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 14, 'draftYear': 2021}},
#   {'id': 85942,
#    'fullName': 'Braden Holt',
#    'link': '/api/v1/draft/prospects/85942',
#    'firstName': 'Braden',
#    'lastName': 'Holt',
#    'birthDate': '2003-07-30',
#    'birthCity': 'Fort Collins',
#    'birthStateProvince': 'CO',
#    'birthCountry': 'USA',
#    'height': '6\' 2"',
#    'weight': 160,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'nhlPlayerId': 8482999,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'name': 'EVERETT', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'WHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 15, 'draftYear': 2021}},
#   {'id': 85361,
#    'fullName': 'Luke Pavicich',
#    'link': '/api/v1/draft/prospects/85361',
#    'firstName': 'Luke',
#    'lastName': 'Pavicich',
#    'birthDate': '2002-03-21',
#    'birthCity': 'Clarence Center',
#    'birthStateProvince': 'NY',
#    'birthCountry': 'USA',
#    'height': '6\' 2"',
#    'weight': 175,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'name': 'UMASS', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'H-EAST', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 16, 'draftYear': 2021}},
#   {'id': 84519,
#    'fullName': 'Remington Keopple',
#    'link': '/api/v1/draft/prospects/84519',
#    'firstName': 'Remington',
#    'lastName': 'Keopple',
#    'birthDate': '2002-03-21',
#    'birthCity': 'Owatonna',
#    'birthStateProvince': 'MN',
#    'birthCountry': 'USA',
#    'height': '6\' 2"',
#    'weight': 196,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'name': 'DES MOINES', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'USHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 19, 'draftYear': 2021}},
#   {'id': 86527,
#    'fullName': 'Kaidan Mbereko',
#    'link': '/api/v1/draft/prospects/86527',
#    'firstName': 'Kaidan',
#    'lastName': 'Mbereko',
#    'birthDate': '2003-07-28',
#    'birthCity': 'Aspen',
#    'birthStateProvince': 'CO',
#    'birthCountry': 'USA',
#    'height': '5\' 11"',
#    'weight': 190,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'name': 'LINCOLN', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'USHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 20, 'draftYear': 2021}},
#   {'id': 82027,
#    'fullName': 'Noah Patenaude',
#    'link': '/api/v1/draft/prospects/82027',
#    'firstName': 'Noah',
#    'lastName': 'Patenaude',
#    'birthDate': '2002-12-24',
#    'birthCity': 'Neuchâtel',
#    'birthCountry': 'CHE',
#    'height': '6\' 1"',
#    'weight': 180,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 4,
#     'shortName': 'Euro Goalie',
#     'name': 'European Goalie'},
#    'amateurTeam': {'name': 'SAINT JOHN', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'QMJHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 21, 'draftYear': 2021}},
#   {'id': 85986,
#    'fullName': 'Jakub Brabenec',
#    'link': '/api/v1/draft/prospects/85986',
#    'firstName': 'Jakub',
#    'lastName': 'Brabenec',
#    'birthDate': '2003-09-11',
#    'birthCity': 'Jihlava',
#    'birthCountry': 'CZE',
#    'height': '6\' 1"',
#    'weight': 174,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'C',
#     'name': 'Center',
#     'type': 'Forward',
#     'abbreviation': 'C'},
#    'nhlPlayerId': 8482724,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'Brno', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'CZREP', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 21, 'draftYear': 2021}},
#   {'id': 92385,
#    'fullName': 'Owen Bartoszkiewicz',
#    'link': '/api/v1/draft/prospects/92385',
#    'firstName': 'Owen',
#    'lastName': 'Bartoszkiewicz',
#    'birthDate': '2003-03-11',
#    'birthCity': 'Alton',
#    'birthStateProvince': 'IL',
#    'birthCountry': 'USA',
#    'height': '6\' 1"',
#    'weight': 193,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'name': 'YOUNGSTOWN', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'USHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 22, 'draftYear': 2021}},
#   {'id': 82572,
#    'fullName': 'Chase Clark',
#    'link': '/api/v1/draft/prospects/82572',
#    'firstName': 'Chase',
#    'lastName': 'Clark',
#    'birthDate': '2002-04-08',
#    'birthCity': 'Williamsville',
#    'birthStateProvince': 'NY',
#    'birthCountry': 'USA',
#    'height': '6\' 6"',
#    'weight': 202,
#    'shootsCatches': 'R',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'nhlPlayerId': 8482939,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'name': 'Jersey Hitmen', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'USPHL - NCDC', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 23, 'draftYear': 2021}},
#   {'id': 89871,
#    'fullName': 'Jed Baliotti',
#    'link': '/api/v1/draft/prospects/89871',
#    'firstName': 'Jed',
#    'lastName': 'Baliotti',
#    'birthDate': '2002-02-07',
#    'birthCity': 'New York',
#    'birthStateProvince': 'NY',
#    'birthCountry': 'USA',
#    'height': '6\' 3"',
#    'weight': 188,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'link': '/api/v1/teams/null'},
#    'amateurLeague': {'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 24, 'draftYear': 2021}},
#   {'id': 77992,
#    'fullName': 'Logan Terness',
#    'link': '/api/v1/draft/prospects/77992',
#    'firstName': 'Logan',
#    'lastName': 'Terness',
#    'birthDate': '2002-09-18',
#    'birthCity': 'North Vancouver',
#    'birthStateProvince': 'BC',
#    'birthCountry': 'CAN',
#    'height': '6\' 0"',
#    'weight': 175,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'name': 'UCONN', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'H-EAST', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 25, 'draftYear': 2021}},
#   {'id': 81716,
#    'fullName': 'Colin Purcell',
#    'link': '/api/v1/draft/prospects/81716',
#    'firstName': 'Colin',
#    'lastName': 'Purcell',
#    'birthDate': '2002-03-26',
#    'birthCity': 'Shaker Heights',
#    'birthStateProvince': 'OH',
#    'birthCountry': 'USA',
#    'height': '6\' 7"',
#    'weight': 205,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'name': 'PENTICTON', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'BCHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 26, 'draftYear': 2021}},
#   {'id': 87134,
#    'fullName': 'Liam Dower Nilsson',
#    'link': '/api/v1/draft/prospects/87134',
#    'firstName': 'Liam',
#    'lastName': 'Dower Nilsson',
#    'birthDate': '2003-04-14',
#    'birthCity': 'Gothenburg',
#    'birthCountry': 'SWE',
#    'height': '6\' 0"',
#    'weight': 172,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'C',
#     'name': 'Center',
#     'type': 'Forward',
#     'abbreviation': 'C'},
#    'nhlPlayerId': 8482764,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'Frolunda Jr.', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'SWEDEN-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 27, 'draftYear': 2021}},
#   {'id': 86446,
#    'fullName': 'William Blackburn',
#    'link': '/api/v1/draft/prospects/86446',
#    'firstName': 'William',
#    'lastName': 'Blackburn',
#    'birthDate': '2003-09-01',
#    'birthCity': 'Jonquiere',
#    'birthStateProvince': 'QC',
#    'birthCountry': 'CAN',
#    'height': '5\' 11"',
#    'weight': 173,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'name': "VAL-D'OR", 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'QMJHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 27, 'draftYear': 2021}},
#   {'id': 77915,
#    'fullName': 'Gage Alexander',
#    'link': '/api/v1/draft/prospects/77915',
#    'firstName': 'Gage',
#    'lastName': 'Alexander',
#    'birthDate': '2002-07-02',
#    'birthCity': 'Okotoks',
#    'birthStateProvince': 'AB',
#    'birthCountry': 'CAN',
#    'height': '6\' 6"',
#    'weight': 205,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'nhlPlayerId': 8482936,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'name': 'Winnipeg', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'WHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 28, 'draftYear': 2021}},
#   {'id': 80473,
#    'fullName': 'Dylan Duke',
#    'link': '/api/v1/draft/prospects/80473',
#    'firstName': 'Dylan',
#    'lastName': 'Duke',
#    'birthDate': '2003-03-04',
#    'birthCity': 'Strongsville',
#    'birthStateProvince': 'OH',
#    'birthCountry': 'USA',
#    'height': '5\' 10"',
#    'weight': 175,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'L',
#     'name': 'Left Wing',
#     'type': 'Forward',
#     'abbreviation': 'LW'},
#    'nhlPlayerId': 8482663,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 1,
#     'shortName': 'NA Skater',
#     'name': 'North American Skater'},
#    'amateurTeam': {'name': 'USA U-18', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'NTDP', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 29, 'draftYear': 2021}},
#   {'id': 90844,
#    'fullName': 'Martin Schreiber',
#    'link': '/api/v1/draft/prospects/90844',
#    'firstName': 'Martin',
#    'lastName': 'Schreiber',
#    'birthDate': '2002-10-31',
#    'birthCity': 'Karlskoga',
#    'birthCountry': 'SWE',
#    'height': '6\' 2"',
#    'weight': 183,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'D',
#     'name': 'Defenseman',
#     'type': 'Defenseman',
#     'abbreviation': 'D'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'LINKOPING JR.', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'SWEDEN-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 29, 'draftYear': 2021}},
#   {'id': 85914,
#    'fullName': 'Owen Millward',
#    'link': '/api/v1/draft/prospects/85914',
#    'firstName': 'Owen',
#    'lastName': 'Millward',
#    'birthDate': '2003-05-01',
#    'birthCity': 'Davis',
#    'birthStateProvince': 'CA',
#    'birthCountry': 'USA',
#    'height': '6\' 3"',
#    'weight': 210,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'link': '/api/v1/teams/null'},
#    'amateurLeague': {'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 29, 'draftYear': 2021}},
#   {'id': 92836,
#    'fullName': 'Cameron Whitehead',
#    'link': '/api/v1/draft/prospects/92836',
#    'firstName': 'Cameron',
#    'lastName': 'Whitehead',
#    'birthDate': '2003-06-13',
#    'birthCity': 'Ottawa',
#    'birthStateProvince': 'ON',
#    'birthCountry': 'CAN',
#    'height': '6\' 3"',
#    'weight': 170,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 1,
#     'shortName': 'NA Skater',
#     'name': 'North American Skater'},
#    'amateurTeam': {'name': 'LINCOLN', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'USHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 30, 'draftYear': 2021}},
#   {'id': 77817,
#    'fullName': 'Koen Macinnes',
#    'link': '/api/v1/draft/prospects/77817',
#    'firstName': 'Koen',
#    'lastName': 'Macinnes',
#    'birthDate': '2002-01-13',
#    'birthCity': 'Port Coquitlam',
#    'birthStateProvince': 'BC',
#    'birthCountry': 'CAN',
#    'height': '6\' 2"',
#    'weight': 195,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'name': 'EVERETT', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'WHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 31, 'draftYear': 2021}},
#   {'id': 87956,
#    'fullName': 'Vladislav Lukashevich',
#    'link': '/api/v1/draft/prospects/87956',
#    'firstName': 'Vladislav',
#    'lastName': 'Lukashevich',
#    'birthDate': '2003-05-23',
#    'birthCity': 'Magadan',
#    'birthCountry': 'RUS',
#    'height': '6\' 2"',
#    'weight': 167,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'D',
#     'name': 'Defenseman',
#     'type': 'Defenseman',
#     'abbreviation': 'D'},
#    'nhlPlayerId': 8482770,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'Yaroslavl 2', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'RUSSIA-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 31, 'draftYear': 2021}},
#   {'id': 82782,
#    'fullName': 'Guillaume Richard',
#    'link': '/api/v1/draft/prospects/82782',
#    'firstName': 'Guillaume',
#    'lastName': 'Richard',
#    'birthDate': '2003-02-10',
#    'birthCity': 'Quebec City',
#    'birthStateProvince': 'QC',
#    'birthCountry': 'CAN',
#    'height': '6\' 2"',
#    'weight': 170,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'D',
#     'name': 'Defenseman',
#     'type': 'Defenseman',
#     'abbreviation': 'D'},
#    'nhlPlayerId': 8482692,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 1,
#     'shortName': 'NA Skater',
#     'name': 'North American Skater'},
#    'amateurTeam': {'name': 'Tri-City', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'USHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 32, 'draftYear': 2021}},
#   {'id': 84824,
#    'fullName': 'Daniil Sobolev',
#    'link': '/api/v1/draft/prospects/84824',
#    'firstName': 'Daniil',
#    'lastName': 'Sobolev',
#    'birthDate': '2003-03-03',
#    'birthCity': 'St. Petersburg',
#    'birthCountry': 'RUS',
#    'height': '6\' 0"',
#    'weight': 210,
#    'shootsCatches': 'R',
#    'primaryPosition': {'code': 'D',
#     'name': 'Defenseman',
#     'type': 'Defenseman',
#     'abbreviation': 'D'},
#    'nhlPlayerId': 8482717,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'Spartak 2', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'RUSSIA-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 32, 'draftYear': 2021}},
#   {'id': 88891,
#    'fullName': 'Vasily Atanasov',
#    'link': '/api/v1/draft/prospects/88891',
#    'firstName': 'Vasily',
#    'lastName': 'Atanasov',
#    'birthDate': '2002-09-25',
#    'birthCity': 'Nizhny Tagil',
#    'birthCountry': 'RUS',
#    'height': '5\' 10"',
#    'weight': 147,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'C',
#     'name': 'Center',
#     'type': 'Forward',
#     'abbreviation': 'C'},
#    'nhlPlayerId': 8482791,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'KHANTY-MANSIYSK 2', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'RUSSIA-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 33, 'draftYear': 2021}},
#   {'id': 88836,
#    'fullName': 'Yaroslav Busygin',
#    'link': '/api/v1/draft/prospects/88836',
#    'firstName': 'Yaroslav',
#    'lastName': 'Busygin',
#    'birthDate': '2003-02-14',
#    'birthCity': 'Korkino',
#    'birthCountry': 'RUS',
#    'height': '6\' 3"',
#    'weight': 185,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'D',
#     'name': 'Defenseman',
#     'type': 'Defenseman',
#     'abbreviation': 'D'},
#    'nhlPlayerId': 8482789,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'PODOLSK 2', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'RUSSIA-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 34, 'draftYear': 2021}},
#   {'id': 84825,
#    'fullName': 'Matvey Petrov',
#    'link': '/api/v1/draft/prospects/84825',
#    'firstName': 'Matvey',
#    'lastName': 'Petrov',
#    'birthDate': '2003-03-12',
#    'birthCity': 'Gus-Khrustalny',
#    'birthCountry': 'RUS',
#    'height': '6\' 2"',
#    'weight': 178,
#    'shootsCatches': 'R',
#    'primaryPosition': {'code': 'L',
#     'name': 'Left Wing',
#     'type': 'Forward',
#     'abbreviation': 'LW'},
#    'nhlPlayerId': 8482718,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'Krylja Sovetov 2', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'RUSSIA-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 35, 'draftYear': 2021}},
#   {'id': 83283,
#    'fullName': 'Conner Roulette',
#    'link': '/api/v1/draft/prospects/83283',
#    'firstName': 'Conner',
#    'lastName': 'Roulette',
#    'birthDate': '2003-05-13',
#    'birthCity': 'Winnipeg',
#    'birthStateProvince': 'MB',
#    'birthCountry': 'CAN',
#    'height': '5\' 11"',
#    'weight': 180,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'L',
#     'name': 'Left Wing',
#     'type': 'Forward',
#     'abbreviation': 'LW'},
#    'nhlPlayerId': 8482709,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 1,
#     'shortName': 'NA Skater',
#     'name': 'North American Skater'},
#    'amateurTeam': {'name': 'Seattle', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'WHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 36, 'draftYear': 2021}},
#   {'id': 89189,
#    'fullName': 'Albert Sjoberg',
#    'link': '/api/v1/draft/prospects/89189',
#    'firstName': 'Albert',
#    'lastName': 'Sjoberg',
#    'birthDate': '2003-03-19',
#    'birthCity': 'Stockholm',
#    'birthCountry': 'SWE',
#    'height': '6\' 0"',
#    'weight': 183,
#    'shootsCatches': 'R',
#    'primaryPosition': {'code': 'R',
#     'name': 'Right Wing',
#     'type': 'Forward',
#     'abbreviation': 'RW'},
#    'nhlPlayerId': 8482910,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'Sodertalje Jr.', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'SWEDEN-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 36, 'draftYear': 2021}},
#   {'id': 89224,
#    'fullName': 'Nikita Grebenkin',
#    'link': '/api/v1/draft/prospects/89224',
#    'firstName': 'Nikita',
#    'lastName': 'Grebenkin',
#    'birthDate': '2003-05-02',
#    'birthCity': 'Serov',
#    'birthCountry': 'RUS',
#    'height': '6\' 2"',
#    'weight': 183,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'R',
#     'name': 'Right Wing',
#     'type': 'Forward',
#     'abbreviation': 'RW'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'MAGNITOGORSK 2', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'RUSSIA-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 37, 'draftYear': 2021}},
#   {'id': 87113,
#    'fullName': 'Topias Vilen',
#    'link': '/api/v1/draft/prospects/87113',
#    'firstName': 'Topias',
#    'lastName': 'Vilen',
#    'birthDate': '2003-04-01',
#    'birthCity': 'Lahti',
#    'birthCountry': 'FIN',
#    'height': '6\' 1"',
#    'weight': 194,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'D',
#     'name': 'Defenseman',
#     'type': 'Defenseman',
#     'abbreviation': 'D'},
#    'nhlPlayerId': 8482873,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'Pelicans', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'FINLAND', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 38, 'draftYear': 2021}},
#   {'id': 79373,
#    'fullName': 'Florian Elias',
#    'link': '/api/v1/draft/prospects/79373',
#    'firstName': 'Florian',
#    'lastName': 'Elias',
#    'birthDate': '2002-08-07',
#    'birthCity': 'Augsburg',
#    'birthCountry': 'DEU',
#    'height': '5\' 8"',
#    'weight': 175,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'C',
#     'name': 'Center',
#     'type': 'Forward',
#     'abbreviation': 'C'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'MANNHEIM', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'GERMANY', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 39, 'draftYear': 2021}},
#   {'id': 89465,
#    'fullName': 'Arvid Sundin',
#    'link': '/api/v1/draft/prospects/89465',
#    'firstName': 'Arvid',
#    'lastName': 'Sundin',
#    'birthDate': '2003-08-02',
#    'birthCity': 'Gavle',
#    'birthCountry': 'SWE',
#    'height': '5\' 11"',
#    'weight': 178,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'L',
#     'name': 'Left Wing',
#     'type': 'Forward',
#     'abbreviation': 'LW'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'BRYNAS JR.', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'SWEDEN-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 40, 'draftYear': 2021}},
#   {'id': 82082,
#    'fullName': 'Jack Bar',
#    'link': '/api/v1/draft/prospects/82082',
#    'firstName': 'Jack',
#    'lastName': 'Bar',
#    'birthDate': '2002-10-07',
#    'birthCity': 'Newmarket',
#    'birthStateProvince': 'ON',
#    'birthCountry': 'CAN',
#    'height': '6\' 2"',
#    'weight': 193,
#    'shootsCatches': 'R',
#    'primaryPosition': {'code': 'D',
#     'name': 'Defenseman',
#     'type': 'Defenseman',
#     'abbreviation': 'D'},
#    'nhlPlayerId': 8482670,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 1,
#     'shortName': 'NA Skater',
#     'name': 'North American Skater'},
#    'amateurTeam': {'name': 'Chicago', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'USHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 41, 'draftYear': 2021}},
#   {'id': 87110,
#    'fullName': 'Aleksi Malinen',
#    'link': '/api/v1/draft/prospects/87110',
#    'firstName': 'Aleksi',
#    'lastName': 'Malinen',
#    'birthDate': '2003-05-26',
#    'birthCity': 'Tuusula',
#    'birthCountry': 'FIN',
#    'height': '6\' 0"',
#    'weight': 176,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'D',
#     'name': 'Defenseman',
#     'type': 'Defenseman',
#     'abbreviation': 'D'},
#    'nhlPlayerId': 8482756,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'JYP', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'FINLAND', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 41, 'draftYear': 2021}},
#   {'id': 82300,
#    'fullName': 'Aidan Hreschuk',
#    'link': '/api/v1/draft/prospects/82300',
#    'firstName': 'Aidan',
#    'lastName': 'Hreschuk',
#    'birthDate': '2003-02-19',
#    'birthCity': 'Long Beach',
#    'birthStateProvince': 'CA',
#    'birthCountry': 'USA',
#    'height': '5\' 11"',
#    'weight': 188,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'D',
#     'name': 'Defenseman',
#     'type': 'Defenseman',
#     'abbreviation': 'D'},
#    'nhlPlayerId': 8482680,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 1,
#     'shortName': 'NA Skater',
#     'name': 'North American Skater'},
#    'amateurTeam': {'name': 'USA U-18', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'NTDP', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 42, 'draftYear': 2021}},
#   {'id': 84851,
#    'fullName': 'Simon Groch',
#    'link': '/api/v1/draft/prospects/84851',
#    'firstName': 'Simon',
#    'lastName': 'Groch',
#    'birthDate': '2003-03-10',
#    'birthCity': 'Bratislava',
#    'birthCountry': 'SVK',
#    'height': '6\' 3"',
#    'weight': 207,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'D',
#     'name': 'Defenseman',
#     'type': 'Defenseman',
#     'abbreviation': 'D'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'OLOMOUC JR.', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'CZREP-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 42, 'draftYear': 2021}},
#   {'id': 87162,
#    'fullName': 'Danil Grigoryev',
#    'link': '/api/v1/draft/prospects/87162',
#    'firstName': 'Danil',
#    'lastName': 'Grigoryev',
#    'birthDate': '2003-05-30',
#    'birthCity': 'Kazan',
#    'birthCountry': 'RUS',
#    'height': '6\' 5"',
#    'weight': 205,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'C',
#     'name': 'Center',
#     'type': 'Forward',
#     'abbreviation': 'C'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'BARS KAZAN', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'RUSSIA-2', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 43, 'draftYear': 2021}},
#   {'id': 84802,
#    'fullName': 'Ryan Ufko',
#    'link': '/api/v1/draft/prospects/84802',
#    'firstName': 'Ryan',
#    'lastName': 'Ufko',
#    'birthDate': '2003-05-07',
#    'birthCity': 'Smithtown',
#    'birthStateProvince': 'NY',
#    'birthCountry': 'USA',
#    'height': '5\' 10"',
#    'weight': 181,
#    'shootsCatches': 'R',
#    'primaryPosition': {'code': 'D',
#     'name': 'Defenseman',
#     'type': 'Defenseman',
#     'abbreviation': 'D'},
#    'nhlPlayerId': 8482715,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 1,
#     'shortName': 'NA Skater',
#     'name': 'North American Skater'},
#    'amateurTeam': {'name': 'Chicago', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'USHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 43, 'draftYear': 2021}},
#   {'id': 87157,
#    'fullName': 'Vladimir Sychov',
#    'link': '/api/v1/draft/prospects/87157',
#    'firstName': 'Vladimir',
#    'lastName': 'Sychov',
#    'birthDate': '2003-03-17',
#    'birthCity': 'Stupino',
#    'birthCountry': 'RUS',
#    'height': '5\' 11"',
#    'weight': 156,
#    'shootsCatches': 'R',
#    'primaryPosition': {'code': 'L',
#     'name': 'Left Wing',
#     'type': 'Forward',
#     'abbreviation': 'LW'},
#    'nhlPlayerId': 8482788,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'SKA-Varyagi', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'RUSSIA-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 44, 'draftYear': 2021}},
#   {'id': 82800,
#    'fullName': 'Dmitriy Zugan',
#    'link': '/api/v1/draft/prospects/82800',
#    'firstName': 'Dmitriy',
#    'lastName': 'Zugan',
#    'birthDate': '2002-11-23',
#    'birthCity': 'Moscow',
#    'birthCountry': 'RUS',
#    'height': '5\' 11"',
#    'weight': 176,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'C',
#     'name': 'Center',
#     'type': 'Forward',
#     'abbreviation': 'C'},
#    'nhlPlayerId': 8482696,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'CSKA 2', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'RUSSIA-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 45, 'draftYear': 2021}},
#   {'id': 86829,
#    'fullName': 'Daniil Lazutin',
#    'link': '/api/v1/draft/prospects/86829',
#    'firstName': 'Daniil',
#    'lastName': 'Lazutin',
#    'birthDate': '2003-07-25',
#    'birthCity': 'Moscow',
#    'birthCountry': 'RUS',
#    'height': '6\' 2"',
#    'weight': 180,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'C',
#     'name': 'Center',
#     'type': 'Forward',
#     'abbreviation': 'C'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'SKA ST. PETERSBURG 2',
#     'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'RUSSIA-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 46, 'draftYear': 2021}},
#   {'id': 86517,
#    'fullName': 'Justin Robidas',
#    'link': '/api/v1/draft/prospects/86517',
#    'firstName': 'Justin',
#    'lastName': 'Robidas',
#    'birthDate': '2003-03-13',
#    'birthCity': 'Plano',
#    'birthCountry': 'USA',
#    'height': '5\' 8"',
#    'weight': 173,
#    'shootsCatches': 'R',
#    'primaryPosition': {'code': 'C',
#     'name': 'Center',
#     'type': 'Forward',
#     'abbreviation': 'C'},
#    'nhlPlayerId': 8482785,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 1,
#     'shortName': 'NA Skater',
#     'name': 'North American Skater'},
#    'amateurTeam': {'name': "Val d'Or", 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'QMJHL', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 47, 'draftYear': 2021}},
#   {'id': 80610,
#    'fullName': 'Elias Vilen',
#    'link': '/api/v1/draft/prospects/80610',
#    'firstName': 'Elias',
#    'lastName': 'Vilen',
#    'birthDate': '2001-01-01',
#    'birthCity': 'Lahti',
#    'birthCountry': 'FIN',
#    'height': '5\' 9"',
#    'weight': 172,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'C',
#     'name': 'Center',
#     'type': 'Forward',
#     'abbreviation': 'C'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'PELICANS', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'FINLAND', 'link': '/api/v1/league/null'},
#    'ranks': {'finalRank': 47, 'draftYear': 2021}},
#   {'id': 87247,
#    'fullName': 'Joel Nystrom',
#    'link': '/api/v1/draft/prospects/87247',
#    'firstName': 'Joel',
#    'lastName': 'Nystrom',
#    'birthDate': '2002-05-14',
#    'birthCity': 'Karlstad',
#    'birthCountry': 'SWE',
#    'height': '5\' 11"',
#    'weight': 170,
#    'shootsCatches': 'R',
#    'primaryPosition': {'code': 'D',
#     'name': 'Defenseman',
#     'type': 'Defenseman',
#     'abbreviation': 'D'},
# ...
#     'abbreviation': 'RW'},
#    'nhlPlayerId': 8482241,
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'Trebic', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'CZREP-2', 'link': '/api/v1/league/null'},
#    'ranks': {}},
#   {'id': 94572,
#    'fullName': 'Vladislav Bakirov',
#    'link': '/api/v1/draft/prospects/94572',
#    'firstName': 'Vladislav',
#    'lastName': 'Bakirov',
#    'birthDate': '2003-06-24',
#    'birthCity': 'Nizhny Tagil',
#    'birthCountry': 'RUS',
#    'height': '6\' 1"',
#    'weight': 179,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'R',
#     'name': 'Right Wing',
#     'type': 'Forward',
#     'abbreviation': 'RW'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'YEKATERINBURG 2', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'RUSSIA-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {}},
#   {'id': 92961,
#    'fullName': 'Cole Quevillon',
#    'link': '/api/v1/draft/prospects/92961',
#    'firstName': 'Cole',
#    'lastName': 'Quevillon',
#    'birthDate': '2003-03-21',
#    'birthCity': '',
#    'height': '6\' 1"',
#    'weight': 180,
#    'shootsCatches': 'R',
#    'primaryPosition': {'code': 'D',
#     'name': 'Defenseman',
#     'type': 'Defenseman',
#     'abbreviation': 'D'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 1,
#     'shortName': 'NA Skater',
#     'name': 'North American Skater'},
#    'amateurTeam': {'name': 'BROCKVILLE', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'CCHL', 'link': '/api/v1/league/null'},
#    'ranks': {}},
#   {'id': 87059,
#    'fullName': 'Stephen Pszeniczny',
#    'link': '/api/v1/draft/prospects/87059',
#    'firstName': 'Stephen',
#    'lastName': 'Pszeniczny',
#    'birthDate': '2003-08-08',
#    'birthCity': '',
#    'shootsCatches': 'R',
#    'primaryPosition': {'code': 'D',
#     'name': 'Defenseman',
#     'type': 'Defenseman',
#     'abbreviation': 'D'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 1,
#     'shortName': 'NA Skater',
#     'name': 'North American Skater'},
#    'amateurTeam': {'link': '/api/v1/teams/null'},
#    'amateurLeague': {'link': '/api/v1/league/null'},
#    'ranks': {}},
#   {'id': 93589,
#    'fullName': 'Eino Ojala',
#    'link': '/api/v1/draft/prospects/93589',
#    'firstName': 'Eino',
#    'lastName': 'Ojala',
#    'birthDate': '2004-03-24',
#    'birthCity': 'Kirkkonummi',
#    'birthCountry': 'FIN',
#    'height': '6\' 0"',
#    'weight': 168,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'L',
#     'name': 'Left Wing',
#     'type': 'Forward',
#     'abbreviation': 'LW'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'HIFK U18', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'FIN-JR. U18', 'link': '/api/v1/league/null'},
#    'ranks': {}},
#   {'id': 83102,
#    'fullName': 'Artyom Mikhailov',
#    'link': '/api/v1/draft/prospects/83102',
#    'firstName': 'Artyom',
#    'lastName': 'Mikhailov',
#    'birthDate': '2001-02-06',
#    'birthCity': '',
#    'birthCountry': 'RUS',
#    'height': '6\' 5"',
#    'weight': 211,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 4,
#     'shortName': 'Euro Goalie',
#     'name': 'European Goalie'},
#    'amateurTeam': {'name': 'KRYLJA SOVETOV 2', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'RUSSIA-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {}},
#   {'id': 91570,
#    'fullName': 'Pavel Savchenko',
#    'link': '/api/v1/draft/prospects/91570',
#    'firstName': 'Pavel',
#    'lastName': 'Savchenko',
#    'birthDate': '2003-12-02',
#    'birthCity': 'Biysk',
#    'birthCountry': 'RUS',
#    'height': '6\' 1"',
#    'weight': 167,
#    'shootsCatches': 'R',
#    'primaryPosition': {'code': 'R',
#     'name': 'Right Wing',
#     'type': 'Forward',
#     'abbreviation': 'RW'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'STUPINO 2', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'RUSSIA-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {}},
#   {'id': 88470,
#    'fullName': 'Kevin Minnoch',
#    'link': '/api/v1/draft/prospects/88470',
#    'firstName': 'Kevin',
#    'lastName': 'Minnoch',
#    'birthDate': '2002-08-27',
#    'birthCity': '',
#    'height': '6\' 0"',
#    'weight': 170,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'D',
#     'name': 'Defenseman',
#     'type': 'Defenseman',
#     'abbreviation': 'D'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 1,
#     'shortName': 'NA Skater',
#     'name': 'North American Skater'},
#    'amateurTeam': {'name': 'SHERWOOD PARK', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'AJHL', 'link': '/api/v1/league/null'},
#    'ranks': {}},
#   {'id': 91882,
#    'fullName': 'Matej Bais',
#    'link': '/api/v1/draft/prospects/91882',
#    'firstName': 'Matej',
#    'lastName': 'Bais',
#    'birthDate': '2003-09-19',
#    'birthCity': '',
#    'birthCountry': 'SVK',
#    'height': '5\' 9"',
#    'weight': 158,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'D',
#     'name': 'Defenseman',
#     'type': 'Defenseman',
#     'abbreviation': 'D'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'B. BYSTRICA JR.', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'SLOVAKIA-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {}},
#   {'id': 92530,
#    'fullName': 'Mike Reinalter',
#    'link': '/api/v1/draft/prospects/92530',
#    'firstName': 'Mike',
#    'lastName': 'Reinalter',
#    'birthDate': '2003-08-09',
#    'birthCity': 'Silandro',
#    'birthCountry': 'ITA',
#    'height': '5\' 10"',
#    'weight': 168,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 4,
#     'shortName': 'Euro Goalie',
#     'name': 'European Goalie'},
#    'amateurTeam': {'name': 'REGENSBURG JR.', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'GERMANY-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {}},
#   {'id': 96058,
#    'fullName': 'Ben Loreto',
#    'link': '/api/v1/draft/prospects/96058',
#    'firstName': 'Ben',
#    'lastName': 'Loreto',
#    'birthDate': '2002-05-30',
#    'birthCity': '',
#    'height': '6\' 0"',
#    'weight': 175,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'D',
#     'name': 'Defenseman',
#     'type': 'Defenseman',
#     'abbreviation': 'D'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 1,
#     'shortName': 'NA Skater',
#     'name': 'North American Skater'},
#    'amateurTeam': {'name': 'TORONTO JC', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'OJHL', 'link': '/api/v1/league/null'},
#    'ranks': {}},
#   {'id': 92832,
#    'fullName': 'Owen Simpson',
#    'link': '/api/v1/draft/prospects/92832',
#    'firstName': 'Owen',
#    'lastName': 'Simpson',
#    'birthDate': '2004-04-04',
#    'birthCity': '',
#    'height': '6\' 2"',
#    'weight': 172,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'D',
#     'name': 'Defenseman',
#     'type': 'Defenseman',
#     'abbreviation': 'D'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 1,
#     'shortName': 'NA Skater',
#     'name': 'North American Skater'},
#    'amateurTeam': {'link': '/api/v1/teams/null'},
#    'amateurLeague': {'link': '/api/v1/league/null'},
#    'ranks': {}},
#   {'id': 86711,
#    'fullName': 'Fabrice Fortin',
#    'link': '/api/v1/draft/prospects/86711',
#    'firstName': 'Fabrice',
#    'lastName': 'Fortin',
#    'birthDate': '2003-05-08',
#    'birthCity': 'Roberval',
#    'birthStateProvince': 'QC',
#    'birthCountry': 'CAN',
#    'height': '5\' 8"',
#    'weight': 178,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'L',
#     'name': 'Left Wing',
#     'type': 'Forward',
#     'abbreviation': 'LW'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 1,
#     'shortName': 'NA Skater',
#     'name': 'North American Skater'},
#    'amateurTeam': {'name': 'CHICOUTIMI', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'QMJHL', 'link': '/api/v1/league/null'},
#    'ranks': {}},
#   {'id': 92191,
#    'fullName': 'Kayden Skulmoski',
#    'link': '/api/v1/draft/prospects/92191',
#    'firstName': 'Kayden',
#    'lastName': 'Skulmoski',
#    'birthDate': '2002-10-03',
#    'birthCity': '',
#    'height': '5\' 10"',
#    'weight': 170,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'D',
#     'name': 'Defenseman',
#     'type': 'Defenseman',
#     'abbreviation': 'D'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 1,
#     'shortName': 'NA Skater',
#     'name': 'North American Skater'},
#    'amateurTeam': {'name': 'GRANDE PRAIRIE', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'AJHL', 'link': '/api/v1/league/null'},
#    'ranks': {}},
#   {'id': 90617,
#    'fullName': 'Valtteri Maurola',
#    'link': '/api/v1/draft/prospects/90617',
#    'firstName': 'Valtteri',
#    'lastName': 'Maurola',
#    'birthDate': '2004-01-10',
#    'birthCity': 'Jyvaskyla',
#    'birthCountry': 'FIN',
#    'height': '5\' 7"',
#    'weight': 154,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'R',
#     'name': 'Right Wing',
#     'type': 'Forward',
#     'abbreviation': 'RW'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'JYP JR.', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'FINLAND-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {}},
#   {'id': 91410,
#    'fullName': 'Filipp Freyer',
#    'link': '/api/v1/draft/prospects/91410',
#    'firstName': 'Filipp',
#    'lastName': 'Freyer',
#    'birthDate': '2003-01-22',
#    'birthCity': 'Barnaul',
#    'birthCountry': 'RUS',
#    'height': '5\' 11"',
#    'weight': 176,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'D',
#     'name': 'Defenseman',
#     'type': 'Defenseman',
#     'abbreviation': 'D'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'IRBIS KAZAN', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'RUSSIA-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {}},
#   {'id': 80514,
#    'fullName': 'Juraj Klain',
#    'link': '/api/v1/draft/prospects/80514',
#    'firstName': 'Juraj',
#    'lastName': 'Klain',
#    'birthDate': '2001-04-04',
#    'birthCity': '',
#    'birthCountry': 'SVK',
#    'height': '5\' 10"',
#    'weight': 168,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 4,
#     'shortName': 'Euro Goalie',
#     'name': 'European Goalie'},
#    'amateurTeam': {'name': 'MARTIN U18', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'SLOVAKIA-JR. U18',
#     'link': '/api/v1/league/null'},
#    'ranks': {}},
#   {'id': 90428,
#    'fullName': 'Charles-Edward Gravel',
#    'link': '/api/v1/draft/prospects/90428',
#    'firstName': 'Charles-Edward',
#    'lastName': 'Gravel',
#    'birthDate': '2004-03-23',
#    'birthCity': 'Levis',
#    'birthStateProvince': 'QC',
#    'birthCountry': 'CAN',
#    'height': '6\' 0"',
#    'weight': 180,
#    'shootsCatches': 'R',
#    'primaryPosition': {'code': 'G',
#     'name': 'Goalie',
#     'type': 'Goalie',
#     'abbreviation': 'G'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 3,
#     'shortName': 'NA Goalie',
#     'name': 'North American Goalie'},
#    'amateurTeam': {'name': 'BLAINVILLE-BOISBRIAND',
#     'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'QMJHL', 'link': '/api/v1/league/null'},
#    'ranks': {}},
#   {'id': 85889,
#    'fullName': 'Joshua Wessels',
#    'link': '/api/v1/draft/prospects/85889',
#    'firstName': 'Joshua',
#    'lastName': 'Wessels',
#    'birthDate': '2003-03-08',
#    'birthCity': '',
#    'height': '5\' 9"',
#    'weight': 175,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'D',
#     'name': 'Defenseman',
#     'type': 'Defenseman',
#     'abbreviation': 'D'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 1,
#     'shortName': 'NA Skater',
#     'name': 'North American Skater'},
#    'amateurTeam': {'name': 'LANGLEY', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'BCHL', 'link': '/api/v1/league/null'},
#    'ranks': {}},
#   {'id': 94799,
#    'fullName': 'Artur Kharisov',
#    'link': '/api/v1/draft/prospects/94799',
#    'firstName': 'Artur',
#    'lastName': 'Kharisov',
#    'birthDate': '2004-05-04',
#    'birthCity': 'Naberezhnye Chelny',
#    'birthCountry': 'RUS',
#    'height': '6\' 2"',
#    'weight': 190,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'D',
#     'name': 'Defenseman',
#     'type': 'Defenseman',
#     'abbreviation': 'D'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'ALMETYEVSK 2', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'RUSSIA-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {}},
#   {'id': 88006,
#    'fullName': 'Adam Andrejko',
#    'link': '/api/v1/draft/prospects/88006',
#    'firstName': 'Adam',
#    'lastName': 'Andrejko',
#    'birthDate': '2002-03-29',
#    'birthCity': '',
#    'birthCountry': 'SVK',
#    'height': '5\' 8"',
#    'weight': 143,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'L',
#     'name': 'Left Wing',
#     'type': 'Forward',
#     'abbreviation': 'LW'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'ZVOLEN JR.', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'SLOVAKIA-JR.', 'link': '/api/v1/league/null'},
#    'ranks': {}},
#   {'id': 82032,
#    'fullName': 'Lars Kieni',
#    'link': '/api/v1/draft/prospects/82032',
#    'firstName': 'Lars',
#    'lastName': 'Kieni',
#    'birthDate': '2002-06-20',
#    'birthCity': 'Chur',
#    'birthCountry': 'CHE',
#    'height': '5\' 10"',
#    'weight': 194,
#    'shootsCatches': 'L',
#    'primaryPosition': {'code': 'D',
#     'name': 'Defenseman',
#     'type': 'Defenseman',
#     'abbreviation': 'D'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 2,
#     'shortName': 'Euro Skater',
#     'name': 'European Skater'},
#    'amateurTeam': {'name': 'ZUG ACADEMY', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'SWISS-2', 'link': '/api/v1/league/null'},
#    'ranks': {}},
#   {'id': 83027,
#    'fullName': 'Nicholas Sova',
#    'link': '/api/v1/draft/prospects/83027',
#    'firstName': 'Nicholas',
#    'lastName': 'Sova',
#    'birthDate': '2002-05-27',
#    'birthCity': '',
#    'height': '6\' 1"',
#    'weight': 198,
#    'shootsCatches': 'R',
#    'primaryPosition': {'code': 'D',
#     'name': 'Defenseman',
#     'type': 'Defenseman',
#     'abbreviation': 'D'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 1,
#     'shortName': 'NA Skater',
#     'name': 'North American Skater'},
#    'amateurTeam': {'name': 'BURLINGTON', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'OJHL', 'link': '/api/v1/league/null'},
#    'ranks': {}},
#   {'id': 88854,
#    'fullName': 'Jonah Copre',
#    'link': '/api/v1/draft/prospects/88854',
#    'firstName': 'Jonah',
#    'lastName': 'Copre',
#    'birthDate': '2003-01-09',
#    'birthCity': 'Elgin',
#    'birthStateProvince': 'IL',
#    'birthCountry': 'USA',
#    'height': '5\' 3"',
#    'weight': 145,
#    'shootsCatches': 'R',
#    'primaryPosition': {'code': 'D',
#     'name': 'Defenseman',
#     'type': 'Defenseman',
#     'abbreviation': 'D'},
#    'draftStatus': 'Elig',
#    'prospectCategory': {'id': 1,
#     'shortName': 'NA Skater',
#     'name': 'North American Skater'},
#    'amateurTeam': {'name': 'WATERLOO', 'link': '/api/v1/teams/null'},
#    'amateurLeague': {'name': 'USHL', 'link': '/api/v1/league/null'},
#    'ranks': {}},
#   ...]}
